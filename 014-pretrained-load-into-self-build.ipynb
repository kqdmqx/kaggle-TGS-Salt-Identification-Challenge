# %%
import gc
from segmentation_models import Unet
# Out:
# D:\Anaconda2\envs\py3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np

# %%
model = Unet(backbone_name='resnet50', encoder_weights='imagenet')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, None, None, 3 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, None, None, 3 9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_35 (ZeroPadding2 (None, None, None, 3 0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, None, None, 6 9408        zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, None, None, 6 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, None, None, 6 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_36 (ZeroPadding2 (None, None, None, 6 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, None, None, 6 0           zero_padding2d_36[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, None, None, 6 256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, None, None, 6 0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, None, None, 6 4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, None, None, 6 0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_37 (ZeroPadding2 (None, None, None, 6 0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_37[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn3 (BatchNormaliz (None, None, None, 6 256         stage1_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu3 (Activation) (None, None, None, 6 0           stage1_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv3 (Conv2D)     (None, None, None, 2 16384       stage1_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, None, None, 2 16384       stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           stage1_unit1_conv3[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, None, None, 2 1024        add_17[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, None, None, 2 0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, None, None, 6 16384       stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, None, None, 6 0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_38 (ZeroPadding2 (None, None, None, 6 0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_38[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn3 (BatchNormaliz (None, None, None, 6 256         stage1_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu3 (Activation) (None, None, None, 6 0           stage1_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv3 (Conv2D)     (None, None, None, 2 16384       stage1_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           stage1_unit2_conv3[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, None, None, 2 1024        add_18[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, None, None, 2 0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, None, None, 6 16384       stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, None, None, 6 0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_39 (ZeroPadding2 (None, None, None, 6 0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_39[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn3 (BatchNormaliz (None, None, None, 6 256         stage1_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu3 (Activation) (None, None, None, 6 0           stage1_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv3 (Conv2D)     (None, None, None, 2 16384       stage1_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           stage1_unit3_conv3[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, None, None, 2 1024        add_19[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, None, None, 2 0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, None, None, 1 32768       stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, None, None, 1 0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_40 (ZeroPadding2 (None, None, None, 1 0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_40[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn3 (BatchNormaliz (None, None, None, 1 512         stage2_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu3 (Activation) (None, None, None, 1 0           stage2_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv3 (Conv2D)     (None, None, None, 5 65536       stage2_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, None, None, 5 131072      stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           stage2_unit1_conv3[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, None, None, 5 2048        add_20[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, None, None, 5 0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, None, None, 1 65536       stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, None, None, 1 0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_41 (ZeroPadding2 (None, None, None, 1 0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_41[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn3 (BatchNormaliz (None, None, None, 1 512         stage2_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu3 (Activation) (None, None, None, 1 0           stage2_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv3 (Conv2D)     (None, None, None, 5 65536       stage2_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           stage2_unit2_conv3[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, None, None, 5 2048        add_21[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, None, None, 5 0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, None, None, 1 65536       stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, None, None, 1 0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_42 (ZeroPadding2 (None, None, None, 1 0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_42[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn3 (BatchNormaliz (None, None, None, 1 512         stage2_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu3 (Activation) (None, None, None, 1 0           stage2_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv3 (Conv2D)     (None, None, None, 5 65536       stage2_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           stage2_unit3_conv3[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, None, None, 5 2048        add_22[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, None, None, 5 0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, None, None, 1 65536       stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, None, None, 1 0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_43 (ZeroPadding2 (None, None, None, 1 0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_43[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn3 (BatchNormaliz (None, None, None, 1 512         stage2_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu3 (Activation) (None, None, None, 1 0           stage2_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv3 (Conv2D)     (None, None, None, 5 65536       stage2_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           stage2_unit4_conv3[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, None, None, 5 2048        add_23[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, None, None, 5 0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, None, None, 2 131072      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, None, None, 2 0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_44 (ZeroPadding2 (None, None, None, 2 0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_44[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu3 (Activation) (None, None, None, 2 0           stage3_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, None, None, 1 524288      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           stage3_unit1_conv3[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, None, None, 1 4096        add_24[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, None, None, 1 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, None, None, 2 262144      stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, None, None, 2 0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_45 (ZeroPadding2 (None, None, None, 2 0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_45[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu3 (Activation) (None, None, None, 2 0           stage3_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           stage3_unit2_conv3[0][0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, None, None, 1 4096        add_25[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, None, None, 1 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, None, None, 2 262144      stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, None, None, 2 0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_46 (ZeroPadding2 (None, None, None, 2 0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_46[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu3 (Activation) (None, None, None, 2 0           stage3_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           stage3_unit3_conv3[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, None, None, 1 4096        add_26[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, None, None, 1 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, None, None, 2 262144      stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, None, None, 2 0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_47 (ZeroPadding2 (None, None, None, 2 0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_47[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu3 (Activation) (None, None, None, 2 0           stage3_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           stage3_unit4_conv3[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, None, None, 1 4096        add_27[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, None, None, 1 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, None, None, 2 262144      stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, None, None, 2 0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_48 (ZeroPadding2 (None, None, None, 2 0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_48[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit5_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu3 (Activation) (None, None, None, 2 0           stage3_unit5_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit5_relu3[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           stage3_unit5_conv3[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, None, None, 1 4096        add_28[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, None, None, 1 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, None, None, 2 262144      stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, None, None, 2 0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_49 (ZeroPadding2 (None, None, None, 2 0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_49[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn3 (BatchNormaliz (None, None, None, 2 1024        stage3_unit6_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu3 (Activation) (None, None, None, 2 0           stage3_unit6_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv3 (Conv2D)     (None, None, None, 1 262144      stage3_unit6_relu3[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           stage3_unit6_conv3[0][0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, None, None, 1 4096        add_29[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, None, None, 1 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, None, None, 5 524288      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, None, None, 5 0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_50 (ZeroPadding2 (None, None, None, 5 0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_50[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn3 (BatchNormaliz (None, None, None, 5 2048        stage4_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu3 (Activation) (None, None, None, 5 0           stage4_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv3 (Conv2D)     (None, None, None, 2 1048576     stage4_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, None, None, 2 2097152     stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, None, 2 0           stage4_unit1_conv3[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, None, None, 2 8192        add_30[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, None, None, 2 0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, None, None, 5 1048576     stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, None, None, 5 0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_51 (ZeroPadding2 (None, None, None, 5 0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_51[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn3 (BatchNormaliz (None, None, None, 5 2048        stage4_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu3 (Activation) (None, None, None, 5 0           stage4_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv3 (Conv2D)     (None, None, None, 2 1048576     stage4_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, None, 2 0           stage4_unit2_conv3[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, None, None, 2 8192        add_31[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, None, None, 2 0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, None, None, 5 1048576     stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, None, None, 5 0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_52 (ZeroPadding2 (None, None, None, 5 0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_52[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn3 (BatchNormaliz (None, None, None, 5 2048        stage4_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu3 (Activation) (None, None, None, 5 0           stage4_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv3 (Conv2D)     (None, None, None, 2 1048576     stage4_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, None, 2 0           stage4_unit3_conv3[0][0]
#                                                                  add_31[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, None, None, 2 8192        add_32[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, None, None, 2 0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, None, None, 2 0           relu1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 3 0           decoder_stage0_upsample[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, None, None, 2 7078144     concatenate_5[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, None, None, 2 0           decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, None, None, 2 590080      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, None, None, 2 0           decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, None, None, 2 0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, None, 7 0           decoder_stage1_upsample[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, None, None, 1 884864      concatenate_6[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, None, None, 1 0           decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, None, None, 1 147584      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, None, None, 1 0           decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, None, None, 1 0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, None, 3 0           decoder_stage2_upsample[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, None, None, 6 221248      concatenate_7[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, None, None, 6 0           decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, None, None, 6 36928       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, None, None, 6 0           decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, None, None, 6 0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, None, None, 1 0           decoder_stage3_upsample[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, None, None, 3 36896       concatenate_8[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, None, None, 3 0           decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, None, None, 3 9248        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, None, None, 3 0           decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, None, None, 3 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, None, None, 1 4624        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, None, None, 1 0           decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, None, None, 1 2320        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, None, None, 1 0           decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, None, None, 1 145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, None, None, 1 0           final_conv[0][0]
# ==================================================================================================
# Total params: 32,558,138
# Trainable params: 32,512,564
# Non-trainable params: 45,574
# __________________________________________________________________________________________________

# %%
for i, layer in enumerate(model.layers):
    print("---layer-{}----".format(i))
    print(model.layers[i].get_config())
    weights = model.layers[i].get_weights()
    print(np.array(weights).shape)
# Out:
# ---layer-0----
# {'batch_input_shape': (None, None, None, 3), 'dtype': 'float32', 'sparse': False, 'name': 'data'}
# (0,)
# ---layer-1----
# {'name': 'bn_data', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': False, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (3, 3)
# ---layer-2----
# {'name': 'zero_padding2d_35', 'trainable': True, 'padding': ((3, 3), (3, 3)), 'data_format': 'channels_last'}
# (0,)
# ---layer-3----
# {'name': 'conv0', 'trainable': True, 'filters': 64, 'kernel_size': (7, 7), 'strides': (2, 2), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 7, 7, 3, 64)
# ---layer-4----
# {'name': 'bn0', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-5----
# {'name': 'relu0', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-6----
# {'name': 'zero_padding2d_36', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-7----
# {'name': 'pooling0', 'trainable': True, 'pool_size': (3, 3), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-8----
# {'name': 'stage1_unit1_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-9----
# {'name': 'stage1_unit1_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-10----
# {'name': 'stage1_unit1_conv1', 'trainable': True, 'filters': 64, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 64, 64)
# ---layer-11----
# {'name': 'stage1_unit1_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-12----
# {'name': 'stage1_unit1_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-13----
# {'name': 'zero_padding2d_37', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-14----
# {'name': 'stage1_unit1_conv2', 'trainable': True, 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 64, 64)
# ---layer-15----
# {'name': 'stage1_unit1_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-16----
# {'name': 'stage1_unit1_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-17----
# {'name': 'stage1_unit1_conv3', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 64, 256)
# ---layer-18----
# {'name': 'stage1_unit1_sc', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 64, 256)
# ---layer-19----
# {'name': 'add_17', 'trainable': True}
# (0,)
# ---layer-20----
# {'name': 'stage1_unit2_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-21----
# {'name': 'stage1_unit2_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-22----
# {'name': 'stage1_unit2_conv1', 'trainable': True, 'filters': 64, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 64)
# ---layer-23----
# {'name': 'stage1_unit2_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-24----
# {'name': 'stage1_unit2_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-25----
# {'name': 'zero_padding2d_38', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-26----
# {'name': 'stage1_unit2_conv2', 'trainable': True, 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 64, 64)
# ---layer-27----
# {'name': 'stage1_unit2_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-28----
# {'name': 'stage1_unit2_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-29----
# {'name': 'stage1_unit2_conv3', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 64, 256)
# ---layer-30----
# {'name': 'add_18', 'trainable': True}
# (0,)
# ---layer-31----
# {'name': 'stage1_unit3_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-32----
# {'name': 'stage1_unit3_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-33----
# {'name': 'stage1_unit3_conv1', 'trainable': True, 'filters': 64, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 64)
# ---layer-34----
# {'name': 'stage1_unit3_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-35----
# {'name': 'stage1_unit3_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-36----
# {'name': 'zero_padding2d_39', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-37----
# {'name': 'stage1_unit3_conv2', 'trainable': True, 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 64, 64)
# ---layer-38----
# {'name': 'stage1_unit3_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 64)
# ---layer-39----
# {'name': 'stage1_unit3_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-40----
# {'name': 'stage1_unit3_conv3', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 64, 256)
# ---layer-41----
# {'name': 'add_19', 'trainable': True}
# (0,)
# ---layer-42----
# {'name': 'stage2_unit1_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-43----
# {'name': 'stage2_unit1_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-44----
# {'name': 'stage2_unit1_conv1', 'trainable': True, 'filters': 128, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 128)
# ---layer-45----
# {'name': 'stage2_unit1_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-46----
# {'name': 'stage2_unit1_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-47----
# {'name': 'zero_padding2d_40', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-48----
# {'name': 'stage2_unit1_conv2', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (2, 2), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 128, 128)
# ---layer-49----
# {'name': 'stage2_unit1_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-50----
# {'name': 'stage2_unit1_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-51----
# {'name': 'stage2_unit1_conv3', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 128, 512)
# ---layer-52----
# {'name': 'stage2_unit1_sc', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (2, 2), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 512)
# ---layer-53----
# {'name': 'add_20', 'trainable': True}
# (0,)
# ---layer-54----
# {'name': 'stage2_unit2_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-55----
# {'name': 'stage2_unit2_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-56----
# {'name': 'stage2_unit2_conv1', 'trainable': True, 'filters': 128, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 128)
# ---layer-57----
# {'name': 'stage2_unit2_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-58----
# {'name': 'stage2_unit2_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-59----
# {'name': 'zero_padding2d_41', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-60----
# {'name': 'stage2_unit2_conv2', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 128, 128)
# ---layer-61----
# {'name': 'stage2_unit2_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-62----
# {'name': 'stage2_unit2_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-63----
# {'name': 'stage2_unit2_conv3', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 128, 512)
# ---layer-64----
# {'name': 'add_21', 'trainable': True}
# (0,)
# ---layer-65----
# {'name': 'stage2_unit3_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-66----
# {'name': 'stage2_unit3_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-67----
# {'name': 'stage2_unit3_conv1', 'trainable': True, 'filters': 128, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 128)
# ---layer-68----
# {'name': 'stage2_unit3_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-69----
# {'name': 'stage2_unit3_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-70----
# {'name': 'zero_padding2d_42', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-71----
# {'name': 'stage2_unit3_conv2', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 128, 128)
# ---layer-72----
# {'name': 'stage2_unit3_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-73----
# {'name': 'stage2_unit3_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-74----
# {'name': 'stage2_unit3_conv3', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 128, 512)
# ---layer-75----
# {'name': 'add_22', 'trainable': True}
# (0,)
# ---layer-76----
# {'name': 'stage2_unit4_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-77----
# {'name': 'stage2_unit4_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-78----
# {'name': 'stage2_unit4_conv1', 'trainable': True, 'filters': 128, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 128)
# ---layer-79----
# {'name': 'stage2_unit4_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-80----
# {'name': 'stage2_unit4_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-81----
# {'name': 'zero_padding2d_43', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-82----
# {'name': 'stage2_unit4_conv2', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 128, 128)
# ---layer-83----
# {'name': 'stage2_unit4_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 128)
# ---layer-84----
# {'name': 'stage2_unit4_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-85----
# {'name': 'stage2_unit4_conv3', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 128, 512)
# ---layer-86----
# {'name': 'add_23', 'trainable': True}
# (0,)
# ---layer-87----
# {'name': 'stage3_unit1_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-88----
# {'name': 'stage3_unit1_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-89----
# {'name': 'stage3_unit1_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 256)
# ---layer-90----
# {'name': 'stage3_unit1_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-91----
# {'name': 'stage3_unit1_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-92----
# {'name': 'zero_padding2d_44', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-93----
# {'name': 'stage3_unit1_conv2', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (2, 2), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 256, 256)
# ---layer-94----
# {'name': 'stage3_unit1_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-95----
# {'name': 'stage3_unit1_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-96----
# {'name': 'stage3_unit1_conv3', 'trainable': True, 'filters': 1024, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 1024)
# ---layer-97----
# {'name': 'stage3_unit1_sc', 'trainable': True, 'filters': 1024, 'kernel_size': (1, 1), 'strides': (2, 2), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 1024)
# ---layer-98----
# {'name': 'add_24', 'trainable': True}
# (0,)
# ---layer-99----
# {'name': 'stage3_unit2_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 1024)
# ---layer-100----
# {'name': 'stage3_unit2_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-101----
# {'name': 'stage3_unit2_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 1024, 256)
# ---layer-102----
# {'name': 'stage3_unit2_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-103----
# {'name': 'stage3_unit2_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-104----
# {'name': 'zero_padding2d_45', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-105----
# {'name': 'stage3_unit2_conv2', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 256, 256)
# ---layer-106----
# {'name': 'stage3_unit2_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-107----
# {'name': 'stage3_unit2_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-108----
# {'name': 'stage3_unit2_conv3', 'trainable': True, 'filters': 1024, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 1024)
# ---layer-109----
# {'name': 'add_25', 'trainable': True}
# (0,)
# ---layer-110----
# {'name': 'stage3_unit3_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 1024)
# ---layer-111----
# {'name': 'stage3_unit3_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-112----
# {'name': 'stage3_unit3_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 1024, 256)
# ---layer-113----
# {'name': 'stage3_unit3_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-114----
# {'name': 'stage3_unit3_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-115----
# {'name': 'zero_padding2d_46', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-116----
# {'name': 'stage3_unit3_conv2', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 256, 256)
# ---layer-117----
# {'name': 'stage3_unit3_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-118----
# {'name': 'stage3_unit3_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-119----
# {'name': 'stage3_unit3_conv3', 'trainable': True, 'filters': 1024, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 1024)
# ---layer-120----
# {'name': 'add_26', 'trainable': True}
# (0,)
# ---layer-121----
# {'name': 'stage3_unit4_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 1024)
# ---layer-122----
# {'name': 'stage3_unit4_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-123----
# {'name': 'stage3_unit4_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 1024, 256)
# ---layer-124----
# {'name': 'stage3_unit4_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-125----
# {'name': 'stage3_unit4_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-126----
# {'name': 'zero_padding2d_47', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-127----
# {'name': 'stage3_unit4_conv2', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 256, 256)
# ---layer-128----
# {'name': 'stage3_unit4_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-129----
# {'name': 'stage3_unit4_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-130----
# {'name': 'stage3_unit4_conv3', 'trainable': True, 'filters': 1024, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 256, 1024)
# ---layer-131----
# {'name': 'add_27', 'trainable': True}
# (0,)
# ---layer-132----
# {'name': 'stage3_unit5_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 1024)
# ---layer-133----
# {'name': 'stage3_unit5_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-134----
# {'name': 'stage3_unit5_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 1024, 256)
# ---layer-135----
# {'name': 'stage3_unit5_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 256)
# ---layer-136----
# {'name': 'stage3_unit5_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-137----
# {'name': 'zero_padding2d_48', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-138----
# ...
# (1, 1, 1, 2048, 512)
# ---layer-169----
# {'name': 'stage4_unit2_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-170----
# {'name': 'stage4_unit2_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-171----
# {'name': 'zero_padding2d_51', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-172----
# {'name': 'stage4_unit2_conv2', 'trainable': True, 'filters': 512, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 512, 512)
# ---layer-173----
# {'name': 'stage4_unit2_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-174----
# {'name': 'stage4_unit2_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-175----
# {'name': 'stage4_unit2_conv3', 'trainable': True, 'filters': 2048, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 2048)
# ---layer-176----
# {'name': 'add_31', 'trainable': True}
# (0,)
# ---layer-177----
# {'name': 'stage4_unit3_bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 2048)
# ---layer-178----
# {'name': 'stage4_unit3_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-179----
# {'name': 'stage4_unit3_conv1', 'trainable': True, 'filters': 512, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 2048, 512)
# ---layer-180----
# {'name': 'stage4_unit3_bn2', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-181----
# {'name': 'stage4_unit3_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-182----
# {'name': 'zero_padding2d_52', 'trainable': True, 'padding': ((1, 1), (1, 1)), 'data_format': 'channels_last'}
# (0,)
# ---layer-183----
# {'name': 'stage4_unit3_conv2', 'trainable': True, 'filters': 512, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 3, 3, 512, 512)
# ---layer-184----
# {'name': 'stage4_unit3_bn3', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 512)
# ---layer-185----
# {'name': 'stage4_unit3_relu3', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-186----
# {'name': 'stage4_unit3_conv3', 'trainable': True, 'filters': 2048, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': False, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (1, 1, 1, 512, 2048)
# ---layer-187----
# {'name': 'add_32', 'trainable': True}
# (0,)
# ---layer-188----
# {'name': 'bn1', 'trainable': True, 'axis': 3, 'momentum': 0.99, 'epsilon': 2e-05, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}
# (4, 2048)
# ---layer-189----
# {'name': 'relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-190----
# {'name': 'decoder_stage0_upsample', 'trainable': True, 'size': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-191----
# {'name': 'concatenate_5', 'trainable': True, 'axis': -1}
# (0,)
# ---layer-192----
# {'name': 'decoder_stage0_conv1', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-193----
# {'name': 'decoder_stage0_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-194----
# {'name': 'decoder_stage0_conv2', 'trainable': True, 'filters': 256, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-195----
# {'name': 'decoder_stage0_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-196----
# {'name': 'decoder_stage1_upsample', 'trainable': True, 'size': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-197----
# {'name': 'concatenate_6', 'trainable': True, 'axis': -1}
# (0,)
# ---layer-198----
# {'name': 'decoder_stage1_conv1', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-199----
# {'name': 'decoder_stage1_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-200----
# {'name': 'decoder_stage1_conv2', 'trainable': True, 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-201----
# {'name': 'decoder_stage1_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-202----
# {'name': 'decoder_stage2_upsample', 'trainable': True, 'size': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-203----
# {'name': 'concatenate_7', 'trainable': True, 'axis': -1}
# (0,)
# ---layer-204----
# {'name': 'decoder_stage2_conv1', 'trainable': True, 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-205----
# {'name': 'decoder_stage2_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-206----
# {'name': 'decoder_stage2_conv2', 'trainable': True, 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-207----
# {'name': 'decoder_stage2_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-208----
# {'name': 'decoder_stage3_upsample', 'trainable': True, 'size': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-209----
# {'name': 'concatenate_8', 'trainable': True, 'axis': -1}
# (0,)
# ---layer-210----
# {'name': 'decoder_stage3_conv1', 'trainable': True, 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-211----
# {'name': 'decoder_stage3_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-212----
# {'name': 'decoder_stage3_conv2', 'trainable': True, 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-213----
# {'name': 'decoder_stage3_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-214----
# {'name': 'decoder_stage4_upsample', 'trainable': True, 'size': (2, 2), 'data_format': 'channels_last'}
# (0,)
# ---layer-215----
# {'name': 'decoder_stage4_conv1', 'trainable': True, 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-216----
# {'name': 'decoder_stage4_relu1', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-217----
# {'name': 'decoder_stage4_conv2', 'trainable': True, 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-218----
# {'name': 'decoder_stage4_relu2', 'trainable': True, 'activation': 'relu'}
# (0,)
# ---layer-219----
# {'name': 'final_conv', 'trainable': True, 'filters': 1, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# (2,)
# ---layer-220----
# {'name': 'sigmoid', 'trainable': True, 'activation': 'sigmoid'}
# (0,)

# %%
help(model.layers[3])
# Out:
# Help on Conv2D in module keras.layers.convolutional object:
#
# class Conv2D(_Conv)
#  |  2D convolution layer (e.g. spatial convolution over images).
#  |
#  |  This layer creates a convolution kernel that is convolved
#  |  with the layer input to produce a tensor of
#  |  outputs. If `use_bias` is True,
#  |  a bias vector is created and added to the outputs. Finally, if
#  |  `activation` is not `None`, it is applied to the outputs as well.
#  |
#  |  When using this layer as the first layer in a model,
#  |  provide the keyword argument `input_shape`
#  |  (tuple of integers, does not include the sample axis),
#  |  e.g. `input_shape=(128, 128, 3)` for 128x128 RGB pictures
#  |  in `data_format="channels_last"`.
#  |
#  |  # Arguments
#  |      filters: Integer, the dimensionality of the output space
#  |          (i.e. the number of output filters in the convolution).
#  |      kernel_size: An integer or tuple/list of 2 integers, specifying the
#  |          width and height of the 2D convolution window.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |      strides: An integer or tuple/list of 2 integers,
#  |          specifying the strides of the convolution along the width and height.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |          Specifying any stride value != 1 is incompatible with specifying
#  |          any `dilation_rate` value != 1.
#  |      padding: one of `"valid"` or `"same"` (case-insensitive).
#  |      data_format: A string,
#  |          one of `channels_last` (default) or `channels_first`.
#  |          The ordering of the dimensions in the inputs.
#  |          `channels_last` corresponds to inputs with shape
#  |          `(batch, height, width, channels)` while `channels_first`
#  |          corresponds to inputs with shape
#  |          `(batch, channels, height, width)`.
#  |          It defaults to the `image_data_format` value found in your
#  |          Keras config file at `~/.keras/keras.json`.
#  |          If you never set it, then it will be "channels_last".
#  |      dilation_rate: an integer or tuple/list of 2 integers, specifying
#  |          the dilation rate to use for dilated convolution.
#  |          Can be a single integer to specify the same value for
#  |          all spatial dimensions.
#  |          Currently, specifying any `dilation_rate` value != 1 is
#  |          incompatible with specifying any stride value != 1.
#  |      activation: Activation function to use
#  |          (see [activations](../activations.md)).
#  |          If you don't specify anything, no activation is applied
#  |          (ie. "linear" activation: `a(x) = x`).
#  |      use_bias: Boolean, whether the layer uses a bias vector.
#  |      kernel_initializer: Initializer for the `kernel` weights matrix
#  |          (see [initializers](../initializers.md)).
#  |      bias_initializer: Initializer for the bias vector
#  |          (see [initializers](../initializers.md)).
#  |      kernel_regularizer: Regularizer function applied to
#  |          the `kernel` weights matrix
#  |          (see [regularizer](../regularizers.md)).
#  |      bias_regularizer: Regularizer function applied to the bias vector
#  |          (see [regularizer](../regularizers.md)).
#  |      activity_regularizer: Regularizer function applied to
#  |          the output of the layer (its "activation").
#  |          (see [regularizer](../regularizers.md)).
#  |      kernel_constraint: Constraint function applied to the kernel matrix
#  |          (see [constraints](../constraints.md)).
#  |      bias_constraint: Constraint function applied to the bias vector
#  |          (see [constraints](../constraints.md)).
#  |
#  |  # Input shape
#  |      4D tensor with shape:
#  |      `(samples, channels, rows, cols)` if data_format='channels_first'
#  |      or 4D tensor with shape:
#  |      `(samples, rows, cols, channels)` if data_format='channels_last'.
#  |
#  |  # Output shape
#  |      4D tensor with shape:
#  |      `(samples, filters, new_rows, new_cols)` if data_format='channels_first'
#  |      or 4D tensor with shape:
#  |      `(samples, new_rows, new_cols, filters)` if data_format='channels_last'.
#  |      `rows` and `cols` values might have changed due to padding.
#  |
#  |  Method resolution order:
#  |      Conv2D
#  |      _Conv
#  |      keras.engine.topology.Layer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filters, kernel_size, strides=(1, 1), padding='valid', data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_config(self)
#  |      Returns the config of the layer.
#  |
#  |      A layer config is a Python dictionary (serializable)
#  |      containing the configuration of a layer.
#  |      The same layer can be reinstantiated later
#  |      (without its trained weights) from this configuration.
#  |
#  |      The config of a layer does not include connectivity
#  |      information, nor the layer class name. These are handled
#  |      by `Container` (one layer of abstraction above).
#  |
#  |      # Returns
#  |          Python dictionary.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _Conv:
#  |
#  |  build(self, input_shape)
#  |      Creates the layer weights.
#  |
#  |      Must be implemented on all layers that have weights.
#  |
#  |      # Arguments
#  |          input_shape: Keras tensor (future input to layer)
#  |              or list/tuple of Keras tensors to reference
#  |              for weight shape computations.
#  |
#  |  call(self, inputs)
#  |      This is where the layer's logic lives.
#  |
#  |      # Arguments
#  |          inputs: Input tensor, or list/tuple of input tensors.
#  |          **kwargs: Additional keyword arguments.
#  |
#  |      # Returns
#  |          A tensor or list/tuple of tensors.
#  |
#  |  compute_output_shape(self, input_shape)
#  |      Computes the output shape of the layer.
#  |
#  |      Assumes that the layer will be built
#  |      to match that input shape provided.
#  |
#  |      # Arguments
#  |          input_shape: Shape tuple (tuple of integers)
#  |              or list of shape tuples (one per output tensor of the layer).
#  |              Shape tuples can include None for free dimensions,
#  |              instead of an integer.
#  |
#  |      # Returns
#  |          An input shape tuple.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from keras.engine.topology.Layer:
#  |
#  |  __call__(self, inputs, **kwargs)
#  |      Wrapper around self.call(), for handling internal references.
#  |
#  |      If a Keras tensor is passed:
#  |          - We call self._add_inbound_node().
#  |          - If necessary, we `build` the layer to match
#  |              the _keras_shape of the input(s).
#  |          - We update the _keras_shape of every input tensor with
#  |              its new shape (obtained via self.compute_output_shape).
#  |              This is done as part of _add_inbound_node().
#  |          - We update the _keras_history of the output tensor(s)
#  |              with the current layer.
#  |              This is done as part of _add_inbound_node().
#  |
#  |      # Arguments
#  |          inputs: Can be a tensor or list/tuple of tensors.
#  |          **kwargs: Additional keyword arguments to be passed to `call()`.
#  |
#  |      # Returns
#  |          Output of the layer's `call` method.
#  |
#  |      # Raises
#  |          ValueError: in case the layer is missing shape information
#  |              for its `build` call.
#  |
#  |  add_loss(self, losses, inputs=None)
#  |      Add losses to the layer.
#  |
#  |      The loss may potentially be conditional on some inputs tensors,
#  |      for instance activity losses are conditional on the layer's inputs.
#  |
#  |      # Arguments
#  |          losses: loss tensor or list of loss tensors
#  |              to add to the layer.
#  |          inputs: input tensor or list of inputs tensors to mark
#  |              the losses as conditional on these inputs.
#  |              If None is passed, the loss is assumed unconditional
#  |              (e.g. L2 weight regularization, which only depends
#  |              on the layer's weights variables, not on any inputs tensors).
#  |
#  |  add_update(self, updates, inputs=None)
#  |      Add updates to the layer.
#  |
#  |      The updates may potentially be conditional on some inputs tensors,
#  |      for instance batch norm updates are conditional on the layer's inputs.
#  |
#  |      # Arguments
#  |          updates: update op or list of update ops
#  |              to add to the layer.
#  |          inputs: input tensor or list of inputs tensors to mark
#  |              the updates as conditional on these inputs.
#  |              If None is passed, the updates are assumed unconditional.
#  |
#  |  add_weight(self, name, shape, dtype=None, initializer=None, regularizer=None, trainable=True, constraint=None)
#  |      Adds a weight variable to the layer.
#  |
#  |      # Arguments
#  |          name: String, the name for the weight variable.
#  |          shape: The shape tuple of the weight.
#  |          dtype: The dtype of the weight.
#  |          initializer: An Initializer instance (callable).
#  |          regularizer: An optional Regularizer instance.
#  |          trainable: A boolean, whether the weight should
#  |              be trained via backprop or not (assuming
#  |              that the layer itself is also trainable).
#  |          constraint: An optional Constraint instance.
#  |
#  |      # Returns
#  |          The created weight variable.
#  |
#  |  assert_input_compatibility(self, inputs)
#  |      Checks compatibility between the layer and provided inputs.
#  |
#  |      This checks that the tensor(s) `input`
#  |      verify the input assumptions of the layer
#  |      (if any). If not, exceptions are raised.
#  |
#  |      # Arguments
#  |          inputs: input tensor or list of input tensors.
#  |
#  |      # Raises
#  |          ValueError: in case of mismatch between
#  |              the provided inputs and the expectations of the layer.
#  |
#  |  compute_mask(self, inputs, mask=None)
#  |      Computes an output mask tensor.
#  |
#  |      # Arguments
#  |          inputs: Tensor or list of tensors.
#  |          mask: Tensor or list of tensors.
#  |
#  |      # Returns
#  |          None or a tensor (or list of tensors,
#  |              one per output tensor of the layer).
#  |
#  |  count_params(self)
#  |      Count the total number of scalars composing the weights.
#  |
#  |      # Returns
#  |          An integer count.
#  |
#  |      # Raises
#  |          RuntimeError: if the layer isn't yet built
#  |              (in which case its weights aren't yet defined).
#  |
#  |  get_input_at(self, node_index)
#  |      Retrieves the input tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A tensor (or list of tensors if the layer has multiple inputs).
#  |
#  |  get_input_mask_at(self, node_index)
#  |      Retrieves the input mask tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple inputs).
#  |
#  |  get_input_shape_at(self, node_index)
#  |      Retrieves the input shape(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple inputs).
#  |
#  |  get_losses_for(self, inputs)
#  |
#  |  get_output_at(self, node_index)
#  |      Retrieves the output tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A tensor (or list of tensors if the layer has multiple outputs).
#  |
#  |  get_output_mask_at(self, node_index)
#  |      Retrieves the output mask tensor(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple outputs).
#  |
#  |  get_output_shape_at(self, node_index)
#  |      Retrieves the output shape(s) of a layer at a given node.
#  |
#  |      # Arguments
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      # Returns
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple outputs).
#  |
#  |  get_updates_for(self, inputs)
#  |
#  |  get_weights(self)
#  |      Returns the current weights of the layer.
#  |
#  |      # Returns
#  |          Weights values as a list of numpy arrays.
#  |
#  |  set_weights(self, weights)
#  |      Sets the weights of the layer, from Numpy arrays.
#  |
#  |      # Arguments
#  |          weights: a list of Numpy arrays. The number
#  |              of arrays and their shape must match
#  |              number of the dimensions of the weights
#  |              of the layer (i.e. it should match the
#  |              output of `get_weights`).
#  |
#  |      # Raises
#  |          ValueError: If the provided weights list does not match the
#  |              layer's specifications.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from keras.engine.topology.Layer:
#  |
#  |  from_config(config) from builtins.type
#  |      Creates a layer from its config.
#  |
#  |      This method is the reverse of `get_config`,
#  |      capable of instantiating the same layer from the config
#  |      dictionary. It does not handle layer connectivity
#  |      (handled by Container), nor weights (handled by `set_weights`).
#  |
#  |      # Arguments
#  |          config: A Python dictionary, typically the
#  |              output of get_config.
#  |
#  |      # Returns
#  |          A layer instance.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from keras.engine.topology.Layer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  built
#  |
#  |  input
#  |      Retrieves the input tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input tensor or list of input tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  input_mask
#  |      Retrieves the input mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input mask tensor (potentially None) or list of input
#  |          mask tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  input_shape
#  |      Retrieves the input shape tuple(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Input shape tuple
#  |          (or list of input shape tuples, one tuple per input tensor).
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  losses
#  |
#  |  non_trainable_weights
#  |
#  |  output
#  |      Retrieves the output tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Output tensor or list of output tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  output_mask
#  |      Retrieves the output mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      # Returns
#  |          Output mask tensor (potentially None) or list of output
#  |          mask tensors.
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  output_shape
#  |      Retrieves the output shape tuple(s) of a layer.
#  |
#  |      Only applicable if the layer has one inbound node,
#  |      or if all inbound nodes have the same output shape.
#  |
#  |      # Returns
#  |          Output shape tuple
#  |          (or list of input shape tuples, one tuple per output tensor).
#  |
#  |      # Raises
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  trainable_weights
#  |
#  |  updates
#  |
#  |  weights

# %% [markdown]
# ## change loss, metric & optimizer

# %%
model.compile('Adam', 'binary_crossentropy', ['binary_accuracy'])

# %%
model.compile('SGD', 'binary_crossentropy', ['binary_accuracy'])
